# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind

data = pd.read_csv('eqtl_sign_merged_result.csv')

plt.figure(figsize=(11.5, 6))

metrics = ['acc', 'precision', 'recall', 'f1']

for i, metric in enumerate(metrics):
    plt.subplot(2, 2, i + 1)
    plt.grid(alpha=0.5, linestyle='--')

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='model', palette="viridis", ci=None,
        capsize=0.2, errwidth=2
    )

    plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=12)
    plt.ylabel('', fontsize=10)
    
    plt.legend([], [], frameon=False)
plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-model.png',dpi=300, bbox_inches = 'tight')    
plt.show()

plt.figure(figsize=(16, 3))
for i, metric in enumerate(metrics):

    plt.subplot(2, 2, i + 1)
    plt.grid(True)

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='model', palette="viridis", ci=None,
        capsize=0.3, errwidth=2
    )
    
    #plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    #plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=10)
    plt.ylabel('value', fontsize=10)
    
    
    if(i == 3):
        plt.legend(title="Model", bbox_to_anchor=(1.3, 0), loc=0, borderaxespad=0)
    else:
        plt.legend([], [], frameon=False)

plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-model-legend.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_12808\3669625686.py:56: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind

data = pd.read_csv('eqtl_sign_merged_result.csv')

plt.figure(figsize=(11, 3))

metrics = ['acc', 'precision', 'recall', 'f1']

for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1)
    plt.grid(alpha=0.5, linestyle='--')

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='embedding', palette="cividis", ci=None,
        capsize=0.2, errwidth=2
    )

    plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=12)
    plt.ylabel('', fontsize=10)
    
    plt.legend([], [], frameon=False)
plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-embedding.png',dpi=300, bbox_inches = 'tight')    
plt.show()

plt.figure(figsize=(16, 3))
for i, metric in enumerate(metrics):

    plt.subplot(2, 2, i + 1)
    plt.grid(True)

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='embedding', palette="cividis", ci=None,
        capsize=0.3, errwidth=2
    )
    
    #plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    #plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=10)
    plt.ylabel('value', fontsize=10)
    
    
    if(i == 3):
        plt.legend(title="Embedding", bbox_to_anchor=(1.3, 0), loc=0, borderaxespad=0)
    else:
        plt.legend([], [], frameon=False)

plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-embedding-legend.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind

data = pd.read_csv('eqtl_sign_merged_result.csv')

plt.figure(figsize=(11, 3))

metrics = ['acc', 'precision', 'recall', 'f1']

for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1)
    plt.grid(alpha=0.5, linestyle='--')

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='tissue', palette="bone", ci=None,
        capsize=0.2, errwidth=2
    )

    plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=12)
    plt.ylabel('', fontsize=10)
    
    plt.legend([], [], frameon=False)
plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-tissue.png',dpi=300, bbox_inches = 'tight')    
plt.show()

plt.figure(figsize=(16, 3))
for i, metric in enumerate(metrics):

    plt.subplot(2, 2, i + 1)
    plt.grid(True)

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='tissue', palette="bone", ci=None,
        capsize=0.3, errwidth=2
    )
    
    #plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    #plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=10)
    plt.ylabel('value', fontsize=10)
    
    
    if(i == 3):
        plt.legend(title="Tissue", bbox_to_anchor=(1.4, 0), loc=0, borderaxespad=0)
    else:
        plt.legend([], [], frameon=False)

plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-tissue-legend.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind

data = pd.read_csv('eqtl_sign_merged_result.csv')

plt.figure(figsize=(11, 3))

metrics = ['acc', 'precision', 'recall', 'f1']

for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1)
    plt.grid(alpha=0.5, linestyle='--')

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='size', palette="pink", ci=None,
        capsize=0.2, errwidth=2
    )

    plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=12)
    plt.ylabel('', fontsize=10)
    
    plt.legend([], [], frameon=False)
plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-size.png',dpi=300, bbox_inches = 'tight')    
plt.show()

plt.figure(figsize=(16, 3))
for i, metric in enumerate(metrics):

    plt.subplot(2, 2, i + 1)
    plt.grid(True)

    sns.barplot(
        x='shuffled', y=metric, data=data,
        hue='size', palette="pink", ci=None,
        capsize=0.3, errwidth=2
    )
    
    #plt.title('average ' + f'{metric.capitalize()}', fontsize=14)
    #plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=10)
    plt.ylabel('value', fontsize=10)
    
    
    if(i == 3):
        plt.legend(title="Model size", bbox_to_anchor=(1.4, 0), loc=0, borderaxespad=0)
    else:
        plt.legend([], [], frameon=False)

plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-hue-size-legend.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

data = pd.read_csv('eqtl_sign_merged_result.csv')

plt.figure(figsize=(10, 3))

metrics = ['acc', 'precision', 'recall', 'f1']

palette = sns.color_palette("twilight", as_cmap=False)

p_values = {}

for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1)
    
    shuffled_yes = data[data['shuffled'] == 'yes'][metric]
    shuffled_no = data[data['shuffled'] == 'no'][metric]

    t_stat, p_val = ttest_ind(shuffled_yes, shuffled_no)
    p_values[metric] = p_val

    n_yes = len(shuffled_yes)
    n_no = len(shuffled_no)

    ax = sns.boxplot(x='shuffled', y=metric, data=data, palette=palette, linewidth=1.2)

    for i, box in enumerate(ax.artists):
        
        median = box.get_ydata()[0]  
        upper = box.get_ydata()[2]  
        lower = box.get_ydata()[1]  
        
        ax.errorbar(i, median, yerr=[[median - lower], [upper - median]], fmt='o', color='black', capsize=4, label='Error bars')
    
    plt.title('average ' + f'{metric.capitalize()}\n'
              #f'({n_yes} samples in "yes", {n_no} samples in "no")\n'
              f'T-test, p<0.001', fontsize=14)
    plt.xlabel('Shuffled?', fontsize=12)
    #plt.ylabel(f'{metric.capitalize()}', fontsize=12)

    plt.grid(alpha=0.5, linestyle='--')

plt.tight_layout()
plt.savefig('eqtl-sign-images/shuffled-all.png',dpi=300, bbox_inches = 'tight')
plt.show()

plt.figure(figsize=(11, 3.5))
for i, metric in enumerate(metrics):
    plt.subplot(1, 4, i + 1)
    
    shuffled_yes = data[data['shuffled'] == 'yes'][metric]
    shuffled_no = data[data['shuffled'] == 'no'][metric]

    t_stat, p_val = ttest_ind(shuffled_yes, shuffled_no)
    p_values[metric] = p_val

    n_yes = len(shuffled_yes)
    n_no = len(shuffled_no)

    ax = sns.boxplot(x='shuffled', y=metric, data=data, palette=palette, linewidth=1.2)

    for i, box in enumerate(ax.artists):
        
        median = box.get_ydata()[0]  
        upper = box.get_ydata()[2]  
        lower = box.get_ydata()[1]  
        
        ax.errorbar(i, median, yerr=[[median - lower], [upper - median]], fmt='o', color='black', capsize=4, label='Error bars')
    
    if(i == 2):
        plt.title('average ' + f'{metric.capitalize()}\n'
              f'({n_yes} samples in "yes",\n {n_no} samples in "no")\n'
              f'T-test, p=0.003', fontsize=14)
    else:
        plt.title('average ' + f'{metric.capitalize()}\n'
              f'({n_yes} samples in "yes",\n {n_no} samples in "no")\n'
              f'T-test, p<0.001', fontsize=14)
    plt.xlabel('Shuffled?', fontsize=12)
    plt.ylabel(f'{metric.capitalize()}', fontsize=12)

    plt.grid(alpha=0.5, linestyle='--')
    plt.tight_layout()
    plt.savefig('eqtl-sign-images/shuffled-all2.png',dpi=300, bbox_inches = 'tight')

print("P-values for each metric:")
for metric, p_val in p_values.items():
    print(f"{metric.capitalize()}: {p_val:.3f}")
# Out:
# P-values for each metric:
# Acc: 0.000
# Precision: 0.000
# Recall: 0.003
# F1: 0.000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_complete = pd.read_csv('eqtl_sign_merged_result.csv')
shuffled_yes_data = data_complete[data_complete['shuffled'] == 'yes']

performance_data = shuffled_yes_data.groupby('tissue')[['acc', 'precision', 'recall', 'f1']].mean().reset_index()
heatmap_data = performance_data.set_index('tissue')[['acc', 'precision', 'recall', 'f1']]

plt.figure(figsize=(6, 4))

sns.heatmap(
    heatmap_data, annot=True, fmt=".2f", cmap="bone_r", 
    cbar_kws={'label': 'Performance'}, linewidths=0.5
)

plt.title("Performance Metrics Across Tissues\neQTL sign prediction", fontsize=16)
plt.xlabel("Performance Metrics", fontsize=12)
plt.ylabel("Tissue", fontsize=12)
plt.tight_layout()

plt.savefig('eqtl-sign-images/tissue-evaluation.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data_complete = pd.read_csv('eqtl_sign_merged_result.csv')
shuffled_yes_data = data_complete[data_complete['shuffled'] == 'yes']

performance_data = shuffled_yes_data.groupby('size')[['acc', 'precision', 'recall', 'f1']].mean().reset_index()
heatmap_data = performance_data.set_index('size')[['acc', 'precision', 'recall', 'f1']]

plt.figure(figsize=(4.8, 4))

sns.heatmap(
    heatmap_data, annot=True, fmt=".2f", cmap="cividis_r", 
    cbar_kws={'label': 'Performance'}, linewidths=0.5
)

plt.title("Performance Metrics Across Input Length\neQTL sign prediction", fontsize=16)
plt.xlabel("Performance Metrics", fontsize=12)
plt.ylabel("Model Size", fontsize=12)
plt.tight_layout()

plt.savefig('eqtl-sign-images/size-evaluation.png',dpi=300, bbox_inches = 'tight')
plt.show()
